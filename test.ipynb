# %%
from ultis import LungCTscan as data
from matplotlib import pyplot as plt

dataset = data(mode='train', data_path='data\CT-scan-dataset')

# %%
from torchvision.transforms import ToPILImage

img, label, oimg = dataset[0]

plt.imshow(ToPILImage()(label))
plt.show()
plt.imshow(ToPILImage()(oimg))
plt.show()
